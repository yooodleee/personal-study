# %%
from wordcloud import WordCloud

# %%
# alice.txt
text = open('./keywords.csv').read()
print(text)
# Out:
# 이달의 키워드_100건,,
# 순위,키워드,Score
# 1,하얼빈,57.565
# 2,시간을 파는 상점,55.262
# 3,사피엔스,52.959
# 4,호모 데우스,34.539
# 4,경제,34.539
# 4,칼의 노래,34.539
# 7,과학,32.189
# 8,줄리언,29.934
# 8,김훈,29.934
# 8,사랑,29.934
# 11,예감은 틀리지 않는다,27.631
# 12,제임스,25.328
# 12,반스,25.328
# 12,김창옥,25.328
# 15,흔한남매,23.026
# 15,만화,23.026
# 15,안중근,23.026
# 15,퀴즈,23.026
# 15,자음과모음,23.026
# 20,단계,20.923
# 21,연애의 기억,20.723
# 21,인문학,20.723
# 21,네트워크,20.723
# 21,알렌,20.723
# 21,흔한남매의 흔한 호기심,20.723
# 21,앨런,20.723
# 27,지구,18.421
# 28,청소년문학,16.118
# 28,정신,16.118
# 28,화학,16.118
# 31,우주,16.094
# 32,특별 칭찬 상장,13.816
# 32,수학,13.816
# 32,트렌드,13.816
# 32,김창옥 TV,13.816
# 32,문과 남자의 과학 공부,13.816
# 32,청소년문학상,13.816
# 32,밀례,13.816
# 32,하라리,13.816
# 32,사건,13.816
# 32,물리학,13.816
# 32,제1회,13.816
# 32,김창옥쇼,13.816
# 32,디 에포크,13.816
# 32,머니 트렌드 2025,13.816
# 32,뉴욕타임스,13.816
# 32,해답,13.816
# 32,생각하는 대로,13.816
# 32,청소년,13.816
# 32,우연은 비켜 가지 않는다,13.816
# 51,정보,12.876
# 51,자기계발,12.876
# 51,문장,12.876
# 51,인류,12.876
# 51,AI,12.876
# 51,목표,12.876
# 57,생각,12.477
# ...

# %%
wordcloud = WordCloud().generate(text)
print(wordcloud)    # 객체 주소값값

# %%
# words_: 객체의 비율의 정보가 담긴 딕셔너리를 반환
wordcloud.words_
# Out:
# {'과학': 1.0,
#  '않는다': 1.0,
#  '김창옥': 1.0,
#  '호기심': 1.0,
#  '트렌드': 1.0,
#  '문과': 1.0,
#  '공부': 1.0,
#  '이달의': 0.5,
#  '키워드_100건': 0.5,
#  '순위': 0.5,
#  '키워드': 0.5,
#  'Score': 0.5,
#  '하얼빈': 0.5,
#  '시간을': 0.5,
#  '파는': 0.5,
#  '상점': 0.5,
#  '사피엔스': 0.5,
#  '호모': 0.5,
#  '데우스': 0.5,
#  '경제': 0.5,
#  '칼의': 0.5,
#  '노래': 0.5,
#  '줄리언': 0.5,
#  '김훈': 0.5,
#  '사랑': 0.5,
#  '예감은': 0.5,
#  '틀리지': 0.5,
#  '제임스': 0.5,
#  '반스': 0.5,
#  '흔한남매': 0.5,
#  '만화': 0.5,
#  '안중근': 0.5,
#  '퀴즈': 0.5,
#  '자음과모음': 0.5,
#  '단계': 0.5,
#  '연애의': 0.5,
#  '기억': 0.5,
#  '인문학': 0.5,
#  '네트워크': 0.5,
#  '알렌': 0.5,
#  '흔한남매의': 0.5,
#  '흔한': 0.5,
#  '앨런': 0.5,
#  '지구': 0.5,
#  '청소년문학': 0.5,
#  '정신': 0.5,
#  '화학': 0.5,
#  '우주': 0.5,
#  '특별': 0.5,
#  '칭찬': 0.5,
#  '상장': 0.5,
#  '수학': 0.5,
#  'TV': 0.5,
#  '남자의': 0.5,
#  '청소년문학상': 0.5,
#  '밀례': 0.5,
#  '하라리': 0.5,
#  '사건': 0.5,
#  '물리학': 0.5,
#  '제1회': 0.5,
#  '김창옥쇼': 0.5,
#  '디': 0.5,
#  '에포크': 0.5,
#  '머니': 0.5,
#  '뉴욕타임스': 0.5,
#  '해답': 0.5,
#  '생각하는': 0.5,
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
plt.imshow(wordcloud)   # worldcloud 객체를 넣으면 워드클라우드 형태의 그래프 생성
plt.axis('off') # 눈금 삭제
plt.show()

# %%
from PIL import Image
import numpy as np

# 이미지 파일을 불러와 ndarray로 바꾼 데이터를 alice_mask에 담아줌
alice_mask = np.array(
    Image.open('./image.png')
)
print(alice_mask)   # 255: 흰색인 픽셀, 0: 검은색인 픽셀
# Out:
# [[[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  ...
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]]

# %%
img = Image.open('./image.png')
imgArray = np.array(img)    # 이미지의 각 셀을 수치로 변환

wordcloud = WordCloud(
    font_path='malgun',
    width=400,
    height=400,
    max_font_size=100,
    background_color='white',
    mask=imgArray,
).generate_from_frequencies(from worworwor)

plt.figure()
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 11
#       1 img = Image.open('./image.png')
#       2 imgArray = np.array(img)    # 이미지의 각 셀을 수치로 변환
#       4 wordcloud = WordCloud(
#       5     font_path='malgun',
#       6     width=400,
#       7     height=400,
#       8     max_font_size=100,
#       9     background_color='white',
#      10     mask=imgArray,
# ---> 11 ).generate_from_frequencies(int(text))
#      13 plt.figure()
#      14 plt.imshow(wordcloud)
#
# ValueError: invalid literal for int() with base 10: '\ufeff이달의 키워드_100건,,\n순위,키워드,Score\n1,하얼빈,57.565\n2,시간을 파는 상점,55.262\n3,사피엔스,52.959\n4,호모 데우스,34.539\n4,경제,34.539\n4,칼의 노래,34.539\n7,과학,32.189\n8,줄리언,29.934\n8,김훈,29.934\n8,사랑,29.934\n11,예감은 틀리지 않는다,

# %%
from wordcloud import STOPWORDS # 불용어로 등록된 단어들들

STOPWORDS.add('said')
print(STOPWORDS)
# Out:
# {'yourselves', 'those', 'he', "can't", "shan't", 'between', 'be', "i'm", 'what', 'is', 'once', 'cannot', "didn't", "they'll", 'theirs', 'hers', 'their', "you've", 'after', 'your', 'himself', 'http', "wasn't", 'www', "wouldn't", 'under', 'and', 'too', "we'll", "weren't", "doesn't", 'get', "we've", "you'll", 'when', 'most', 'or', 'we', "who's", 'own', 'an', 'for', 'that', 'this', 'both', 'no', "i'll", "she'll", 'then', 'again', 'at', "won't", "it's", "shouldn't", "hasn't", 'i', 'however', 'same', 'you', 'down', 'it', 'having', 'therefore', "he'll", 'herself', 'whom', 'like', 'off', "how's", "they'd", 'the', 'would', 'of', 'these', 'they', 'which', "don't", 'was', 'out', "they're", 'with', 'before', 'ourselves', 'otherwise', "couldn't", 'so', "where's", 'yourself', 'been', "he's", 'are', 'in', "i'd", "haven't", 'our', 'nor', "you're", 'about', 'any', 'below', 'during', "that's", 'through', "we'd", 'said', 'his', 'ours', 'since', "she's", 'from', 'how', 'could', 'does', "why's", 'who', '
# ...

# %%
wordcloud = WordCloud(
    max_words=100,
    font_path='/usr/share/fonts/truetype/nanum/NanumGothicExtraBold.ttf',
    stopwords=STOPWORDS
).generate(text)    # 'said' 사라짐

plt.figure(figsize=(15, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
from konlpy.tag import Twitter
from collections import Counter

# %%
# open으로 txt파일을 열고 read()를 이용하여 읽는다.
text = open('test.txt').read() 


twitter = Twitter()

# twitter함수를 통해 읽어들인 내용의 형태소를 분석한다.
sentences_tag = []
sentences_tag = twitter.pos(text) 

noun_adj_list = []


# tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어준다.
for word, tag in sentences_tag:
    if tag in ['Noun' , 'Adjective']: 
        noun_adj_list.append(word)


# 가장 많이 나온 단어부터 40개를 저장한다.
counts = Counter(noun_adj_list)
tags = counts.most_common(40) 


# WordCloud를 생성한다.
# 한글을 분석하기위해 font를 한글로 지정해주어야 된다. macOS는 .otf , window는 .ttf 파일의 위치를
# 지정해준다. (ex. '/Font/GodoM.otf')
wc = WordCloud(font_path=[otf 파일의 위치],background_color="white", max_font_size=60)
cloud = wc.generate_from_frequencies(dict(tags))


# 생성된 WordCloud를 test.jpg로 보낸다.
cloud.to_file('test.jpg')

# %%
from wordcloud import WordCloud

# 워드클라우드 모양을 변형하고자 하는 이미지 활용
from PIL import Image

# 그래프 출력
import matplotlib.pyplot as plt

# 수칙 연산 
import numpy as np

# 데이터 핸들링
import pandas as pd

# %%
# 데이터 프레임 생성
df = pd.read_csv('./202412_키워드드.csv', encoding="utf-8")

# 생성된 데이터 프레임을 딕셔너리로 변환
wc = df.set_index("title").to_dict()["count"]

# %%
worldCloud = WordCloud(
    font_path='malgun',
    width=400,
    height=400,
    max_font_size=100,
    background_color='white',
).generate_from_frequencies(wc) # 워드 클라우드 빈도수 지정

# %%
plt.figure()
plt.imshow(worldCloud)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(399.5), np.float64(-0.5))

# %%
img = Image.open('./image.png')
imgArray = np.array(img)    # 이미지의 각 셀을 수치로 변환

worldCloud = WordCloud(
    font_path='malgun',
    width=400,
    height=400,
    max_font_size=100,
    background_color='white',
    mask=imgArray,
).generate_from_frequencies(wc)

plt.figure()
plt.imshow(worldCloud)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(359.5), np.float64(359.5), np.float64(-0.5))
